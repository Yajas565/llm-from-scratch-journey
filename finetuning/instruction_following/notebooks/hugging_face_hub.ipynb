# %%
from huggingface_hub import HfApi

api = HfApi()

api.create_repo(repo_id="YAJAS1/gpt2-finetuned", private=True)

api.upload_file(
    path_or_fileobj="model_and_optimizer_instruction.pth",
    path_in_repo="model_and_optimizer_instruction.pth",
    repo_id="YAJAS1/gpt2-finetuned",
    token=""
)
# Out:
# Processing Files (1 / 1): 100%|██████████| 4.98GB / 4.98GB, 3.13MB/s
# New Data Upload: 100%|██████████|  927MB /  927MB, 3.13MB/s
# CommitInfo(commit_url='https://huggingface.co/YAJAS1/gpt2-finetuned/commit/6c5a9e9e77e6a416b0e172bb1dcfb9f7b010b6ef', commit_message='Upload model_and_optimizer_instruction.pth with huggingface_hub', commit_description='', oid='6c5a9e9e77e6a416b0e172bb1dcfb9f7b010b6ef', pr_url=None, repo_url=RepoUrl('https://huggingface.co/YAJAS1/gpt2-finetuned', endpoint='https://huggingface.co', repo_type='model', repo_id='YAJAS1/gpt2-finetuned'), pr_revision=None, pr_num=None)
